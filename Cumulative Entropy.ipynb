# %%
import numpy as np
import random
import math

# %%
arr = [10 + random.randint(1, 1000) for i in xrange(1000)]

# %%
hist, bin_edges = np.histogram(arr, density=True)

# %%
cdf = np.cumsum(hist*np.diff(bin_edges))

# %%
cdff = [cd * math.log(cd, 2) for cd in cdf]

# %%
-sum(cdff * np.diff(bin_edges))
# Out:
# 355.31693631679752

# %%
arr2 = np.random.randint(1, 100, 1000)

# %%
arr2
# Out:
# array([96,  6, 31, 96, 89, 90, 64, 30, 12, 61, 69, 94, 95, 35, 90, 16,  9,
#        91,  6, 29, 80, 45, 54, 16,  1, 81, 85,  4, 74, 32, 74, 62, 46, 22,
#        70, 80, 17, 40, 80, 20, 16, 99, 34, 99, 45, 51, 50, 19, 99, 85, 18,
#        23, 63, 28, 94, 75, 69,  7, 26, 91, 88, 22, 26, 33, 96, 81, 48, 17,
#        98,  5, 52, 26, 57, 87, 84, 27,  7,  8, 54,  4, 32, 57, 97, 76, 68,
#        41,  8, 70, 74, 18, 40,  5, 60, 50, 16, 44, 99, 32, 44, 16, 18, 69,
#        49, 45, 21,  8, 65, 64, 63, 75, 43, 32, 79, 54, 84, 74, 47, 34, 14,
#        11, 40, 16, 89, 10, 32, 24,  9, 41, 96, 39, 92, 53, 58, 67, 60, 79,
#        27, 90, 27, 85, 88, 33, 11, 34, 54, 72, 96, 14, 93, 69, 62, 32,  8,
#         3, 89, 24,  5, 72, 86, 21, 71, 53, 73, 71,  3, 71, 46, 28, 95, 25,
#        22, 67, 76, 11, 42, 89, 59, 74, 58, 15,  4, 86,  9, 19, 81, 54, 10,
#        81, 55, 38, 80, 80, 87, 85, 30,  3,  7, 40, 82,  3, 56, 91, 51, 18,
#        65, 98,  5, 91, 40, 13, 33, 63, 71, 42, 80, 41, 30, 16, 54, 47, 59,
#        80, 25, 24, 56,  3, 27, 49, 75, 77,  7, 27, 76, 85, 68, 65, 40, 20,
#        73, 99, 88, 19, 31,  5, 37, 52, 27, 18, 52,  1, 34, 80,  6, 23, 54,
#        47,  1,  3, 87, 20, 10,  5, 19, 44,  7, 10,  9, 81, 80, 33, 12, 12,
#        19, 13, 87, 23, 55, 33, 90, 25, 27, 52, 64, 40, 63, 84,  9, 29, 53,
#        51, 43, 99, 35, 98,  2, 15, 53, 33, 33, 73, 36, 49, 33, 57, 80, 45,
#        32, 47, 59, 68, 96, 19, 74, 80, 92, 96, 16, 48,  4,  8, 41, 66, 37,
#        58, 83, 71,  6, 66, 85, 88, 64, 89, 65, 47, 64, 45, 76, 41, 31, 72,
#        92, 87, 43, 14, 76, 76, 26, 72, 43, 24, 82, 78, 41, 22, 20,  1, 39,
#        69,  9, 35,  2, 86, 56,  3, 45, 14, 86, 75, 82, 69, 19, 20, 88, 46,
#        64, 28, 34, 46, 56, 83, 49, 75,  3, 17, 65, 28, 85, 35,  9, 30, 87,
#        75, 99, 23, 46, 28, 94, 79, 35,  3,  2, 90, 35, 98, 16, 96, 77, 70,
#        33, 70, 67, 86, 20, 45, 11,  3, 96, 59, 68, 44, 74, 17, 24, 67, 73,
#         6, 44, 96, 81, 73, 14, 59, 68, 74, 52, 77, 34, 18, 89, 28, 72, 21,
#        56, 94, 14, 76, 15, 53, 40, 74, 71,  3, 63, 91, 39, 70, 50, 14, 60,
#        65, 80, 72, 42, 97, 35, 85, 18, 64, 80, 10, 29,  5, 91, 22, 49, 32,
#        31, 94, 18, 51,  3, 38, 74, 79, 38, 13, 35, 34,  4, 48, 72, 21, 25,
#        27, 66, 75, 11, 43, 57, 66, 81, 55,  9, 43,  6, 96, 85, 71, 89, 33,
#        88, 84, 74,  3, 44, 86, 12,  3, 33, 41, 38, 53, 22, 17, 69,  4, 54,
#        83,  5, 38, 27, 11, 32, 94, 80, 21, 41, 29, 76, 32, 31, 20, 43, 85,
#        85, 70, 48, 82, 51, 74, 30, 41, 17, 68, 22, 23,  3, 27, 52, 54,  6,
#        33, 10, 54, 59, 93, 19, 89, 14, 62, 67, 32, 66, 65, 75, 18, 58, 33,
#        38, 36, 66, 85, 77, 17, 75, 86, 79, 19, 30, 41, 43, 62, 19, 32, 53,
#        87, 54,  6, 67, 53, 36, 21, 52, 22, 36, 91,  8, 33, 73, 69, 95, 15,
#        86, 40, 36, 89, 50, 32, 35, 98, 99, 39, 24,  3, 10, 46, 83, 21, 22,
#        73, 72, 76, 39, 46, 97, 50, 58, 37, 24, 36,  3, 92, 30, 70, 24, 59,
#        73, 73, 29, 47, 26, 22,  8, 63, 53, 18, 94, 96, 81, 65, 56, 93,  7,
#        98, 95, 90, 35, 89, 43, 38, 53, 10, 47, 81, 76, 13, 41, 95, 11, 10,
#        18, 52, 39, 78, 81, 65, 43, 93, 23, 41, 73, 20, 85, 19, 69, 11, 23,
#        79, 24, 90, 33, 57,  9, 35, 60, 33, 90, 95, 77,  9, 55, 42, 47, 92,
#        42, 15, 27, 73, 78, 36, 53, 94, 29, 87, 94, 98, 51, 37, 82, 55, 15,
#        45,  6, 12, 98, 29, 55, 41, 91, 86, 78, 94, 28, 27, 50, 49, 20,  5,
#        40, 37, 15, 29, 89, 18, 88, 28, 47, 22, 68, 13, 16, 79, 90, 24, 30,
#        61, 56, 14, 93, 54, 26, 70, 54, 45, 69, 73, 44, 46, 55, 33, 43, 47,
#        36, 68, 55, 53, 16, 29, 53, 54, 10, 71, 99, 46, 51,  4, 75,  9, 72,
#        46, 84, 32,  2,  4,  7, 70, 80, 70, 38, 59, 98, 91, 94, 78, 18, 96,
#        29,  2, 69, 56, 51,  3, 31, 15, 22, 78, 63, 74, 21, 49,  7, 55, 70,
#        85,  7, 56, 93, 70, 84, 76, 16, 15, 64, 80, 78, 49,  6, 43, 26, 92,
#        81, 81, 54, 63,  4, 28, 24, 28, 48, 14, 13, 94, 33, 29, 80,  5,  1,
#        90, 91, 85, 79, 68, 86, 27, 58, 92, 93, 29, 81,  7, 28, 56, 60, 43,
#        81, 94, 89, 23, 62, 97, 93, 58, 76, 56, 45, 55, 71, 57, 75,  5, 90,
#        44, 16,  1, 17, 18, 81, 90, 88, 14, 73, 29,  2, 15, 47, 14, 61, 25,
#        95, 16, 85, 63, 46, 42, 75,  8, 75,  1, 66, 82, 28, 12, 14, 66, 51,
#        97, 18, 55, 36, 64, 89, 91, 78,  4, 76, 41, 75, 21,  7, 89, 62, 99,
#        89, 17, 72, 12, 73, 79, 90, 19, 67, 20, 72, 85, 45, 92, 57, 88,  9,
#        36, 74, 35, 54, 73, 92,  4, 50,  5, 95, 66, 96, 32, 73, 14, 96,  2,
#        14, 60, 67, 90,  8, 44, 13,  3, 22, 38, 86, 22, 84, 12])

# %%
arr_x = arr2
arr_y = [i+10 for i in arr_x]

# %%
arr_y
# Out:
# [106,
#  16,
#  41,
#  106,
#  99,
#  100,
#  74,
#  40,
#  22,
#  71,
#  79,
#  104,
#  105,
#  45,
#  100,
#  26,
#  19,
#  101,
#  16,
#  39,
#  90,
#  55,
#  64,
#  26,
#  11,
#  91,
#  95,
#  14,
#  84,
#  42,
#  84,
#  72,
#  56,
#  32,
#  80,
#  90,
#  27,
#  50,
#  90,
#  30,
#  26,
#  109,
#  44,
#  109,
#  55,
#  61,
#  60,
#  29,
#  109,
#  95,
#  28,
#  33,
#  73,
#  38,
#  104,
#  85,
#  79,
#  17,
#  36,
#  101,
#  98,
#  32,
#  36,
#  43,
#  106,
#  91,
#  58,
#  27,
#  108,
#  15,
#  62,
#  36,
#  67,
#  97,
#  94,
#  37,
#  17,
#  18,
#  64,
#  14,
#  42,
#  67,
#  107,
#  86,
#  78,
#  51,
#  18,
#  80,
#  84,
#  28,
#  50,
#  15,
#  70,
#  60,
#  26,
#  54,
#  109,
#  42,
#  54,
#  26,
#  28,
#  79,
#  59,
#  55,
#  31,
#  18,
#  75,
#  74,
#  73,
#  85,
#  53,
#  42,
#  89,
#  64,
#  94,
#  84,
#  57,
#  44,
#  24,
#  21,
#  50,
#  26,
#  99,
#  20,
#  42,
#  34,
#  19,
#  51,
#  106,
#  49,
#  102,
#  63,
#  68,
#  77,
#  70,
#  89,
#  37,
#  100,
#  37,
#  95,
#  98,
#  43,
#  21,
#  44,
#  64,
#  82,
#  106,
#  24,
#  103,
#  79,
#  72,
#  42,
#  18,
#  13,
#  99,
#  34,
#  15,
#  82,
#  96,
#  31,
#  81,
#  63,
#  83,
#  81,
#  13,
#  81,
#  56,
#  38,
#  105,
#  35,
#  32,
#  77,
#  86,
#  21,
#  52,
#  99,
#  69,
#  84,
#  68,
#  25,
#  14,
#  96,
#  19,
#  29,
#  91,
#  64,
#  20,
#  91,
#  65,
#  48,
#  90,
#  90,
#  97,
#  95,
#  40,
#  13,
#  17,
#  50,
#  92,
#  13,
#  66,
#  101,
#  61,
#  28,
#  75,
#  108,
#  15,
#  101,
#  50,
#  23,
#  43,
#  73,
#  81,
#  52,
#  90,
#  51,
#  40,
#  26,
#  64,
#  57,
#  69,
#  90,
#  35,
#  34,
#  66,
#  13,
#  37,
#  59,
#  85,
#  87,
#  17,
#  37,
#  86,
#  95,
#  78,
#  75,
#  50,
#  30,
#  83,
#  109,
#  98,
#  29,
#  41,
#  15,
#  47,
#  62,
#  37,
#  28,
#  62,
#  11,
#  44,
#  90,
#  16,
#  33,
#  64,
#  57,
#  11,
#  13,
#  97,
#  30,
#  20,
#  15,
#  29,
#  54,
#  17,
#  20,
#  19,
#  91,
#  90,
#  43,
#  22,
#  22,
#  29,
#  23,
#  97,
#  33,
#  65,
#  43,
#  100,
#  35,
#  37,
#  62,
#  74,
#  50,
#  73,
#  94,
#  19,
#  39,
#  63,
#  61,
#  53,
#  109,
#  45,
#  108,
#  12,
#  25,
#  63,
#  43,
#  43,
#  83,
#  46,
#  59,
#  43,
#  67,
#  90,
#  55,
#  42,
#  57,
#  69,
#  78,
#  106,
#  29,
#  84,
#  90,
#  102,
#  106,
#  26,
#  58,
#  14,
#  18,
#  51,
#  76,
#  47,
#  68,
#  93,
#  81,
#  16,
#  76,
#  95,
#  98,
#  74,
#  99,
#  75,
#  57,
#  74,
#  55,
#  86,
#  51,
#  41,
#  82,
#  102,
#  97,
#  53,
#  24,
#  86,
#  86,
#  36,
#  82,
#  53,
#  34,
#  92,
#  88,
#  51,
#  32,
#  30,
#  11,
#  49,
#  79,
#  19,
#  45,
#  12,
#  96,
#  66,
#  13,
#  55,
#  24,
#  96,
#  85,
#  92,
#  79,
#  29,
#  30,
#  98,
#  56,
#  74,
#  38,
#  44,
#  56,
#  66,
#  93,
#  59,
#  85,
#  13,
#  27,
#  75,
#  38,
#  95,
#  45,
#  19,
#  40,
#  97,
#  85,
#  109,
#  33,
#  56,
#  38,
#  104,
#  89,
#  45,
#  13,
#  12,
#  100,
#  45,
#  108,
#  26,
#  106,
#  87,
#  80,
#  43,
#  80,
#  77,
#  96,
#  30,
#  55,
#  21,
#  13,
#  106,
#  69,
#  78,
#  54,
#  84,
#  27,
#  34,
#  77,
#  83,
#  16,
#  54,
#  106,
#  91,
#  83,
#  24,
#  69,
#  78,
#  84,
#  62,
#  87,
#  44,
#  28,
#  99,
#  38,
#  82,
#  31,
#  66,
#  104,
#  24,
#  86,
#  25,
#  63,
#  50,
#  84,
#  81,
#  13,
#  73,
#  101,
#  49,
#  80,
#  60,
#  24,
#  70,
#  75,
#  90,
#  82,
#  52,
#  107,
#  45,
#  95,
#  28,
#  74,
#  90,
#  20,
#  39,
#  15,
#  101,
#  32,
#  59,
#  42,
#  41,
#  104,
#  28,
#  61,
#  13,
#  48,
#  84,
#  89,
#  48,
#  23,
#  45,
#  44,
#  14,
#  58,
#  82,
#  31,
#  35,
#  37,
#  76,
#  85,
#  21,
#  53,
#  67,
#  76,
#  91,
#  65,
#  19,
#  53,
#  16,
#  106,
#  95,
#  81,
#  99,
#  43,
#  98,
#  94,
#  84,
#  13,
#  54,
#  96,
#  22,
#  13,
#  43,
#  51,
#  48,
#  63,
#  32,
#  27,
#  79,
#  14,
#  64,
#  93,
#  15,
#  48,
#  37,
#  21,
#  42,
#  104,
#  90,
#  31,
#  51,
#  39,
#  86,
#  42,
#  41,
#  30,
#  53,
#  95,
#  95,
#  80,
#  58,
#  92,
#  61,
#  84,
#  40,
#  51,
#  27,
#  78,
#  32,
#  33,
#  13,
#  37,
#  62,
#  64,
#  16,
#  43,
#  20,
#  64,
#  69,
#  103,
#  29,
#  99,
#  24,
#  72,
#  77,
#  42,
#  76,
#  75,
#  85,
#  28,
#  68,
#  43,
#  48,
#  46,
#  76,
#  95,
#  87,
#  27,
#  85,
#  96,
#  89,
#  29,
#  40,
#  51,
#  53,
#  72,
#  29,
#  42,
#  63,
#  97,
#  64,
#  16,
#  77,
#  63,
#  46,
#  31,
#  62,
#  32,
#  46,
#  101,
#  18,
#  43,
#  83,
#  79,
#  105,
#  25,
#  96,
#  50,
#  46,
#  99,
#  60,
#  42,
#  45,
#  108,
#  109,
#  49,
#  34,
#  13,
#  20,
#  56,
#  93,
#  31,
#  32,
#  83,
#  82,
#  86,
#  49,
#  56,
#  107,
#  60,
#  68,
#  47,
#  34,
#  46,
#  13,
#  102,
#  40,
#  80,
#  34,
#  69,
#  83,
#  83,
#  39,
#  57,
#  36,
#  32,
#  18,
#  73,
#  63,
#  28,
#  104,
#  106,
#  91,
#  75,
#  66,
#  103,
#  17,
#  108,
#  105,
#  100,
#  45,
#  99,
#  53,
#  48,
#  63,
#  20,
#  57,
#  91,
#  86,
#  23,
#  51,
#  105,
#  21,
#  20,
#  28,
#  62,
#  49,
#  88,
#  91,
#  75,
#  53,
#  103,
#  33,
#  51,
#  83,
#  30,
#  95,
#  29,
#  79,
#  21,
#  33,
#  89,
#  34,
#  100,
#  43,
#  67,
#  19,
#  45,
#  70,
#  43,
#  100,
#  105,
#  87,
#  19,
#  65,
#  52,
#  57,
#  102,
#  52,
#  25,
#  37,
#  83,
#  88,
#  46,
#  63,
#  104,
#  39,
#  97,
#  104,
#  108,
#  61,
#  47,
#  92,
#  65,
#  25,
#  55,
#  16,
#  22,
#  108,
#  39,
#  65,
#  51,
#  101,
#  96,
#  88,
#  104,
#  38,
#  37,
#  60,
#  59,
#  30,
#  15,
#  50,
#  47,
#  25,
#  39,
#  99,
#  28,
#  98,
#  38,
#  57,
#  32,
#  78,
#  23,
#  26,
#  89,
#  100,
#  34,
#  40,
#  71,
#  66,
#  24,
#  103,
#  64,
#  36,
#  80,
#  64,
#  55,
#  79,
#  83,
#  54,
#  56,
#  65,
#  43,
#  53,
#  57,
#  46,
#  78,
#  65,
#  63,
#  26,
#  39,
#  63,
#  64,
#  20,
#  81,
#  109,
#  56,
#  61,
#  14,
#  85,
#  19,
#  82,
#  56,
#  94,
#  42,
#  12,
#  14,
#  17,
#  80,
#  90,
#  80,
#  48,
#  69,
#  108,
#  101,
#  104,
#  88,
#  28,
#  106,
#  39,
#  12,
#  79,
#  66,
#  61,
#  13,
#  41,
#  25,
#  32,
#  88,
#  73,
#  84,
#  31,
#  59,
#  17,
#  65,
#  80,
#  95,
#  17,
#  66,
#  103,
#  80,
#  94,
#  86,
#  26,
#  25,
#  74,
#  90,
#  88,
#  59,
#  16,
#  53,
#  36,
#  102,
#  91,
#  91,
#  64,
#  73,
#  14,
#  38,
#  34,
#  38,
#  58,
#  24,
#  23,
#  104,
#  43,
#  39,
#  90,
#  15,
#  11,
#  100,
#  101,
#  95,
#  89,
#  78,
#  96,
#  37,
#  68,
#  102,
#  103,
#  39,
#  91,
#  17,
#  38,
#  66,
#  70,
#  53,
#  91,
#  104,
#  99,
#  33,
#  72,
#  107,
#  103,
#  68,
#  86,
#  66,
#  55,
#  65,
#  81,
#  67,
#  85,
#  15,
#  100,
#  54,
#  26,
#  11,
#  27,
#  28,
#  91,
#  100,
#  98,
#  24,
#  83,
#  39,
#  12,
#  25,
#  57,
#  24,
#  71,
#  35,
#  105,
#  26,
#  95,
#  73,
#  56,
#  52,
#  85,
#  18,
#  85,
#  11,
#  76,
#  92,
#  38,
#  22,
#  24,
#  76,
#  61,
#  107,
#  28,
#  65,
#  46,
#  74,
#  99,
#  101,
#  88,
#  14,
#  86,
#  51,
#  85,
#  31,
#  17,
#  99,
#  72,
#  109,
#  99,
#  27,
#  82,
#  22,
#  83,
#  89,
#  100,
#  29,
#  77,
#  30,
#  82,
#  95,
#  55,
#  102,
#  67,
#  98,
#  19,
#  46,
#  84,
#  45,
#  64,
#  83,
#  102,
#  14,
#  60,
#  15,
#  105,
#  76,
#  106,
#  42,
#  83,
#  24,
#  106,
#  12,
#  24,
#  70,
#  77,
#  100,
#  18,
#  54,
#  23,
#  13,
#  32,
#  48,
#  96,
#  32,
#  94,
#  22]

# %%
hist, bin_edges = np.histogram(arr_x, density=True)

# %%
hist
# Out:
# array([ 0.01102041,  0.01102041,  0.01020408,  0.01      ,  0.00897959,
#         0.00989796,  0.00806122,  0.01132653,  0.01112245,  0.01040816])

# %%
bin_edges
# Out:
# array([  1. ,  10.8,  20.6,  30.4,  40.2,  50. ,  59.8,  69.6,  79.4,
#         89.2,  99. ])

# %%
hist, bin_edges = np.histogram(arr_y, density=True)

# %%
hist
# Out:
# array([ 0.01102041,  0.01102041,  0.01020408,  0.01      ,  0.00897959,
#         0.00989796,  0.00806122,  0.01132653,  0.01112245,  0.01040816])
